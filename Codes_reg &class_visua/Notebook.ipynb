# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
from pycaret.regression import *
build = setup(train, target='Target', use_gpu=True)
# Out:
# <style type="text/css">
# #T_9a18c_row16_col1, #T_9a18c_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9a18c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a18c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9a18c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a18c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a18c_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_9a18c_row0_col1" class="data row0 col1" >7367</td>
#     </tr>
#     <tr>
#       <th id="T_9a18c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9a18c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9a18c_row1_col1" class="data row1 col1" >Target</td>
#     </tr>
#     <tr>
#       <th id="T_9a18c_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# %time
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_504a1 th {
#   text-align: left;
# }
# ...

# %%
model_et = create_model('et')
# Out:
# <style type="text/css">
# #T_d212f_row10_col0, #T_d212f_row10_col1, #T_d212f_row10_col2, #T_d212f_row10_col3, #T_d212f_row10_col4, #T_d212f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d212f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d212f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d212f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d212f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d212f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d212f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d212f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
print(model_et)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=-1, oob_score=False,
#                     random_state=7367, verbose=0, warm_start=False)

# %%
evaluate_model(best_model_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
predictions = predict_model(model_et, data=test)
predictions.head()
# Out:
#              timestamp  active_power_calculated_by_converter  \
# 0  2021-05-06 15:02:00                             15.507537
# 1  2021-12-04 06:11:00                            472.577255
# 2  2021-08-31 19:03:00                            447.829615
# 3  2021-09-19 19:01:00                            254.014336
# 4  2021-04-04 02:21:00                           1174.930566
#
#    active_power_raw  ambient_temperature  generator_speed  \
# 0         19.956882            40.233264       410.538834
# 1        478.373881            12.306687       965.077563
# 2        451.158264            29.106771       948.035899
# 3        249.438965            27.074900       804.963776
# 4       1202.654077            32.148434      1199.754858
#
#    generator_winding_temp_max  grid_power10min_average  nc1_inside_temp  \
# 0                   57.357366                84.008399        48.826597
# 1                   51.796727               492.531362        27.457511
# ...

# %%
submission = pd.DataFrame(predictions, columns=['Label'])
submission.rename(columns={'Label': 'Target'}, inplace=True)
submission.head()
# Out:
#       Target
# 0  50.106908
# 1  41.048170
# 2  48.237443
# 3  45.154547
# 4  45.449445

# %%
submission.to_csv('submission.csv', index=False)
